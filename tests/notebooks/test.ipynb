# %%
# !cargo run -- ../models/integrator.mo -t ../templates/casadi.jinja  > test.py
# %load_ext autoreload
# %autoreload 2
import test
import matplotlib.pyplot as plt
integrator = test.Integrator()
res = integrator.simulate()
plt.plot(res['t'], res['x'])
# Out:
#     Finished `dev` profile [unoptimized + debuginfo] target(s) in 0.08s
#      Running `/home/jgoppert/git/rumoca_parol/target/debug/rumoca ../models/integrator.mo -t ../templates/casadi.jinja`
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
